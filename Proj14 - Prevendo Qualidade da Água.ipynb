# %% [markdown]
# # **Prevendo a Qualidade da Água**

# %% [markdown]
# **Objetivo**
#
# * Criar um algoritmo de machine learning capaz de prever se a água é ou não potável.

# %% [markdown]
# ### **1. Introdução**
#
# <p align="justify">
# Em um mundo onde a escassez de água potável se torna uma preocupação cada vez mais crítica, a capacidade de prever a qualidade da água é de suma importância. Neste projeto, embarcaremos em uma jornada para desenvolver um modelo de machine learning que nos permitirá determinar se uma amostra de água é potável ou não, com base em uma série de atributos e características.
#
# <p align="justify">
# A qualidade da água é influenciada por diversos fatores, como concentração de minerais, níveis de poluentes, pH, turbidez e muito mais. A tarefa de classificar a água como potável ou não é complexa e requer a análise de um conjunto de dados abrangente. É nesse cenário que o PyCaret, uma biblioteca Python para aprendizado de máquina automatizado, entra em cena.
#
# <p align="justify">
# O PyCaret simplifica o processo de construção, treinamento e avaliação de modelos de machine learning, permitindo que os cientistas de dados e engenheiros de machine learning se concentrem mais nas análises e menos na codificação. Neste projeto, utilizaremos o PyCaret para ajudar a escolher o melhor modelo para prever a qualidade da água.
#
# <p align="justify">
# Nosso objetivo é criar um modelo que seja capaz de fornecer previsões precisas e confiáveis sobre a potabilidade da água com base nos atributos coletados.

# %%
# Instalando biblioteca

# !pip install pycaret

# %%
# Carregando bibliotecas

import numpy as np
import pandas as pd

from pycaret.classification import *
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

# %%
# Carregando base de dados

dados = pd.read_csv('/content/drive/MyDrive/Ciência de Dados com Python/Projetos/Dados/Qualidade_da_Agua.csv', sep = ',')

# %%
# Visualizando dados

dados.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %% [markdown]
# ### **2. Análise Exporatória de Dados**

# %%
# Informações sobre o dataset

dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
# Verificando a existência de valores faltantes

dados.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
# Realizando contagem das classes

## 0: não potável
## 1: potável

dados['Potability'].value_counts()
# Out:
# 0    1998
# 1    1278
# Name: Potability, dtype: int64

# %% [markdown]
# ### **3. Pré-Processamento de Dados**

# %%
# Removendo valores faltantes

dados = dados.dropna()

## DEVE-SE TER MUITO CUIDADO AO MODO COMO OS VALORES FALTANTES SERÃO REMOVIDOS
## NEM SEMPRE EXCLUÍ-LOS É A OPÇÃO MAIS ADEQUADA

# %%
# Escolhendo o algoritmo mais adequado para o estudo

clf = setup(dados, target = "Potability", session_id = 0)
compare_models()
# Out:
# <style type="text/css">
# #T_fc3f3_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fc3f3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc3f3_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_fc3f3_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc3f3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc3f3_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_fc3f3_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc3f3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fc3f3_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_fc3f3_row1_col1" class="data row1 col1" >Potability</td>
#     </tr>
#     <tr>
#       <th id="T_fc3f3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fc3f3_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_fc3f3_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_fc3f3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fc3f3_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_fc3f3_row3_col1" class="data row3 col1" >(2011, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_fc3f3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fc3f3_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_fc3f3_row4_col1" class="data row4 col1" >(2011, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_fc3f3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fc3f3_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_fc3f3_row5_col1" class="data row5 col1" >(1407, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_fc3f3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fc3f3_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_fc3f3_row6_col1" class="data row6 col1" >(604, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_fc3f3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fc3f3_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_fc3f3_row7_col1" class="data row7 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_fc3f3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fc3f3_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_fc3f3_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_fc3f3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fc3f3_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_fc3f3_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_fc3f3_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_fc3f3_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_fc3f3_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_fc3f3_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_fc3f3_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_fc3f3_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_fc3f3_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_fc3f3_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_fc3f3_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_fc3f3_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_fc3f3_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_fc3f3_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_fc3f3_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_fc3f3_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_fc3f3_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_fc3f3_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_fc3f3_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_fc3f3_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fc3f3_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_fc3f3_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_fc3f3_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fc3f3_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_fc3f3_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_fc3f3_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_fc3f3_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_fc3f3_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_fc3f3_row18_col1" class="data row18 col1" >1e94</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6de94 th {
#   text-align: left;
# }
# #T_6de94_row0_col0, #T_6de94_row0_col3, #T_6de94_row1_col0, #T_6de94_row1_col1, #T_6de94_row1_col2, #T_6de94_row1_col3, #T_6de94_row1_col4, #T_6de94_row1_col5, #T_6de94_row1_col6, #T_6de94_row1_col7, #T_6de94_row2_col0, #T_6de94_row2_col1, #T_6de94_row2_col2, #T_6de94_row2_col3, #T_6de94_row2_col4, #T_6de94_row2_col5, #T_6de94_row2_col6, #T_6de94_row2_col7, #T_6de94_row3_col0, #T_6de94_row3_col1, #T_6de94_row3_col2, #T_6de94_row3_col3, #T_6de94_row3_col4, #T_6de94_row3_col5, #T_6de94_row3_col6, #T_6de94_row3_col7, #T_6de94_row4_col0, #T_6de94_row4_col1, #T_6de94_row4_col2, #T_6de94_row4_col3, #T_6de94_row4_col4, #T_6de94_row4_col5, #T_6de94_row4_col6, #T_6de94_row4_col7, #T_6de94_row5_col0, #T_6de94_row5_col1, #T_6de94_row5_col2, #T_6de94_row5_col3, #T_6de94_row5_col4, #T_6de94_row5_col5, #T_6de94_row5_col6, #T_6de94_row5_col7, #T_6de94_row6_col0, #T_6de94_row6_col1, #T_6de94_row6_col2, #T_6de94_row6_col3, #T_6de94_row6_col4, #T_6de94_row6_col5, #T_6de94_row6_col6, #T_6de94_row6_col7, #T_6de94_row7_col0, #T_6de94_row7_col1, #T_6de94_row7_col2, #T_6de94_row7_col3, #T_6de94_row7_col4, #T_6de94_row7_col5, #T_6de94_row7_col6, #T_6de94_row7_col7, #T_6de94_row8_col0, #T_6de94_row8_col1, #T_6de94_row8_col2, #T_6de94_row8_col3, #T_6de94_row8_col4, #T_6de94_row8_col5, #T_6de94_row8_col6, #T_6de94_row8_col7, #T_6de94_row9_col0, #T_6de94_row9_col1, #T_6de94_row9_col2, #T_6de94_row9_col3, #T_6de94_row9_col4, #T_6de94_row9_col5, #T_6de94_row9_col6, #T_6de94_row9_col7, #T_6de94_row10_col0, #T_6de94_row10_col1, #T_6de94_row10_col2, #T_6de94_row10_col3, #T_6de94_row10_col4, #T_6de94_row10_col5, #T_6de94_row10_col6, #T_6de94_row10_col7, #T_6de94_row11_col0, #T_6de94_row11_col1, #T_6de94_row11_col2, #T_6de94_row11_col3, #T_6de94_row11_col4, #T_6de94_row11_col5, #T_6de94_row11_col6, #T_6de94_row11_col7, #T_6de94_row12_col0, #T_6de94_row12_col1, #T_6de94_row12_col2, #T_6de94_row12_col3, #T_6de94_row12_col4, #T_6de94_row12_col5, #T_6de94_row12_col6, #T_6de94_row12_col7, #T_6de94_row13_col0, #T_6de94_row13_col1, #T_6de94_row13_col2, #T_6de94_row13_col3, #T_6de94_row13_col4, #T_6de94_row13_col5, #T_6de94_row13_col6, #T_6de94_row13_col7, #T_6de94_row14_col0, #T_6de94_row14_col1, #T_6de94_row14_col2, #T_6de94_row14_col4, #T_6de94_row14_col5, #T_6de94_row14_col6, #T_6de94_row14_col7 {
#   text-align: left;
# }
# #T_6de94_row0_col1, #T_6de94_row0_col2, #T_6de94_row0_col4, #T_6de94_row0_col5, #T_6de94_row0_col6, #T_6de94_row0_col7, #T_6de94_row14_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_6de94_row0_col8, #T_6de94_row1_col8, #T_6de94_row2_col8, #T_6de94_row3_col8, #T_6de94_row4_col8, #T_6de94_row5_col8, #T_6de94_row6_col8, #T_6de94_row7_col8, #T_6de94_row8_col8, #T_6de94_row9_col8, #T_6de94_row11_col8, #T_6de94_row12_col8, #T_6de94_row13_col8, #T_6de94_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_6de94_row10_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_6de94" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6de94_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6de94_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_6de94_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_6de94_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_6de94_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_6de94_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_6de94_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_6de94_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_6de94_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6de94_level0_row0" class="row_heading level0 row0" >qda</th>
#       <td id="T_6de94_row0_col0" class="data row0 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_6de94_row0_col1" class="data row0 col1" >0.6986</td>
#       <td id="T_6de94_row0_col2" class="data row0 col2" >0.7164</td>
#       <td id="T_6de94_row0_col3" class="data row0 col3" >0.4235</td>
#       <td id="T_6de94_row0_col4" class="data row0 col4" >0.7156</td>
#       <td id="T_6de94_row0_col5" class="data row0 col5" >0.5287</td>
#       <td id="T_6de94_row0_col6" class="data row0 col6" >0.3292</td>
#       <td id="T_6de94_row0_col7" class="data row0 col7" >0.3552</td>
#       <td id="T_6de94_row0_col8" class="data row0 col8" >0.0730</td>
#     </tr>
#     <tr>
#       <th id="T_6de94_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_6de94_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_6de94_row1_col1" class="data row1 col1" >0.6666</td>
#       <td id="T_6de94_row1_col2" class="data row1 col2" >0.6916</td>
#       <td id="T_6de94_row1_col3" class="data row1 col3" >0.3792</td>
#       <td id="T_6de94_row1_col4" class="data row1 col4" >0.6506</td>
#       <td id="T_6de94_row1_col5" class="data row1 col5" >0.4779</td>
#       <td id="T_6de94_row1_col6" class="data row1 col6" >0.2572</td>
#       <td id="T_6de94_row1_col7" class="data row1 col7" >0.2783</td>
#       <td id="T_6de94_row1_col8" class="data row1 col8" >0.5000</td>
#     </tr>
#     <tr>
#       <th id="T_6de94_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_6de94_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_6de94_row2_col1" class="data row2 col1" >0.6652</td>
#       <td id="T_6de94_row2_col2" class="data row2 col2" >0.7038</td>
#       <td id="T_6de94_row2_col3" class="data row2 col3" >0.3563</td>
#       <td id="T_6de94_row2_col4" class="data row2 col4" >0.6569</td>
#       <td id="T_6de94_row2_col5" class="data row2 col5" >0.4586</td>
#       <td id="T_6de94_row2_col6" class="data row2 col6" >0.2479</td>
#       <td id="T_6de94_row2_col7" class="data row2 col7" >0.2731</td>
#       <td id="T_6de94_row2_col8" class="data row2 col8" >0.1780</td>
#     </tr>
#     <tr>
#       <th id="T_6de94_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_6de94_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_6de94_row3_col1" class="data row3 col1" >0.6503</td>
#       <td id="T_6de94_row3_col2" class="data row3 col2" >0.6773</td>
#       <td id="T_6de94_row3_col3" class="data row3 col3" >0.4427</td>
#       <td id="T_6de94_row3_col4" class="data row3 col4" >0.5876</td>
#       <td id="T_6de94_row3_col5" class="data row3 col5" >0.5040</td>
#       <td id="T_6de94_row3_col6" class="data row3 col6" >0.2426</td>
#       <td id="T_6de94_row3_col7" class="data row3 col7" >0.2488</td>
#       <td id="T_6de94_row3_col8" class="data row3 col8" >0.8610</td>
#     </tr>
#     <tr>
#       <th id="T_6de94_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_6de94_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_6de94_row4_col1" class="data row4 col1" >0.6425</td>
#       <td id="T_6de94_row4_col2" class="data row4 col2" >0.6525</td>
#       <td id="T_6de94_row4_col3" class="data row4 col3" >0.3474</td>
#       <td id="T_6de94_row4_col4" class="data row4 col4" >0.6013</td>
#       <td id="T_6de94_row4_col5" class="data row4 col5" >0.4392</td>
#       <td id="T_6de94_row4_col6" class="data row4 col6" >0.2030</td>
#       <td id="T_6de94_row4_col7" class="data row4 col7" >0.2205</td>
#       <td id="T_6de94_row4_col8" class="data row4 col8" >0.2920</td>
#     </tr>
#     <tr>
#       <th id="T_6de94_level0_row5" class="row_heading level0 row5" >xgboost</th>
#       <td id="T_6de94_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_6de94_row5_col1" class="data row5 col1" >0.6403</td>
#       <td id="T_6de94_row5_col2" class="data row5 col2" >0.6732</td>
#       <td id="T_6de94_row5_col3" class="data row5 col3" >0.4567</td>
#       <td id="T_6de94_row5_col4" class="data row5 col
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]
# QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001)

# %% [markdown]
# * O resultado acima mostra que o melhor modelo para o estudo é o QDA.

# %%
# Separando os dados em previsores e classes

previsores = dados.drop('Potability', axis = 1)
classes = dados['Potability']

# %%
# Dividindo os dados em treino e teste

X_treino, X_teste, y_treino, y_teste = train_test_split(previsores,
                                                        classes,
                                                        test_size = 0.3,
                                                        random_state = 0)

# %%
# Distribuição dos dados

print(X_treino.shape)
print(y_treino.shape)
print(X_teste.shape)
print(y_teste.shape)
# Out:
# (1407, 9)
# (1407,)
# (604, 9)
# (604,)

# %% [markdown]
# ### **4. Construindo Modelo**

# %%
# Carregando biblioteca

from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# %%
# Instânciando modelo

modelo = QuadraticDiscriminantAnalysis(priors = None,
                                       reg_param = 0.0,
                                       store_covariance = False,
                                       tol = 0.0001)

# %%
# Treinando modelo

modelo.fit(X_treino, y_treino)
# Out:
# QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001)

# %%
# Aplicando modelo treinado aos dados de teste

y_predito = modelo.predict(X_teste)

# %% [markdown]
# ### **5. Avaliando Modelo**

# %%
# Métricas do modelo

print(classification_report(y_teste, y_predito))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.88      0.77       367
#            1       0.67      0.39      0.50       237
#
#     accuracy                           0.69       604
#    macro avg       0.68      0.63      0.63       604
# weighted avg       0.68      0.69      0.66       604

# %%
# Acurácia do modelo

accuracy_score(y_teste, y_predito)
# Out:
# 0.6870860927152318

# %% [markdown]
# ### **6. Considerações Finais**
#
# <p align="justify">
# Utilizando o PyCaret, chegou-se a conclusão que o melhor modelo era o QDA (Quadratic Discriminant Analysis). A partir das métricas obtidas pode-se considerar o desempenho do modelo como razoável, com margens para melhorar. Acredito que com a utilização de um algoritmo mais robusto e alguns processamentos nos dados a serem realizados na etapa de pré-processamento de dados possam melhorar o desempenho do modelo ou de outro que venha a ser construido.
